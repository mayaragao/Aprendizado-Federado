# %%
import re
import pandas as pd
import matplotlib.pyplot as plt
from numpy import mean, std, arange
from math import sqrt

# %% [markdown]
# #### Leitura dos resultados do método original, sem amostragem:

# %%
results1 = open("Resultado_cliente_1.txt", 'r')
results2 = open("Resultado_cliente_2.txt", 'r')
results3 = open("Resultado_cliente_3.txt", 'r')
results4 = open("Resultado_cliente_4.txt", 'r')
results5 = open("Resultado_cliente_5.txt", 'r')
results6 = open("Resultado_cliente_6.txt", 'r')
results7 = open("Resultado_cliente_7.txt", 'r')
results8 = open("Resultado_cliente_8.txt", 'r')
results9 = open("Resultado_cliente_9.txt", 'r')
results10 = open("Resultado_cliente_10.txt", 'r')

Lines1 = results1.readlines()
Lines2 = results2.readlines()
Lines3 = results3.readlines()
Lines4 = results4.readlines()
Lines5 = results5.readlines()
Lines6 = results6.readlines()
Lines7 = results7.readlines()
Lines8 = results8.readlines()
Lines9 = results9.readlines()
Lines10 = results10.readlines()

# %%
accuracies = [[],[],[],[],[],[],[],[],[],[]]
losses = [[],[],[],[],[],[],[],[],[],[]]

for line in Lines1:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[0].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[0].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines2:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[1].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[1].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines3:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[2].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[2].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines4:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[3].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[3].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines5:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[4].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[4].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines6:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[5].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[5].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines7:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[6].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[6].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines8:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[7].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[7].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines9:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[8].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[8].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines10:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[9].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[9].append(float(line.split(':')[2][1:].split(' ')[0]))

# %%
x1Mean = mean(accuracies,axis=0);
x1Interval = std(accuracies,axis=0)*1.96/sqrt(10);
x1Interval = std(accuracies,axis=0)
x = arange(len(x1Mean))

# %%
print( x1Mean[-1]*100,' \pm ', x1Interval[-1]*100)
# Out:
# 77.927  \pm  4.606391320762924

# %%
media1 = mean([accuracies[0], accuracies[1]],axis=0)*100
desvio1 = std([accuracies[0], accuracies[1]],axis=0)*100
media2 = mean([accuracies[2], accuracies[3]],axis=0)*100
desvio2 = std([accuracies[2], accuracies[3]],axis=0)*100
media3 = mean([accuracies[4], accuracies[5]],axis=0)*100
desvio3 = std([accuracies[4], accuracies[5]],axis=0)*100
media4 = mean([accuracies[6], accuracies[7]],axis=0)*100
desvio4 = std([accuracies[6], accuracies[7]],axis=0)*100
media5 = mean([accuracies[8], accuracies[9]],axis=0)*100
desvio5 = std([accuracies[8], accuracies[9]],axis=0)*100
print('Resultados originais 2100 amostras')
print('1 e 2 :', media1[-1],' \pm ', desvio1[-1])
print('3 e 4 :', media2[-1],' \pm ', desvio2[-1])
print('5 e 6 :', media3[-1],' \pm ', desvio3[-1])
print('7 e 8 :', media4[-1],' \pm ', desvio4[-1])
print('9 e 10 :', media5[-1],' \pm ', desvio5[-1])
# Out:
# Resultados originais 2100 amostras
# 1 e 2 : 82.32  \pm  0.6799999999999973
# 3 e 4 : 70.47  \pm  0.09000000000000119
# 5 e 6 : 74.91  \pm  0.880000000000003
# 7 e 8 : 81.935  \pm  0.06499999999999839
# 9 e 10 : 80.0  \pm  0.6899999999999962

# %% [markdown]
# #### Leitura dos resultados do com amostragem de 325 elementos:

# %%
results1 = open("/content/Rand325/Resultado_cliente_1.txt", 'r')
results2 = open("/content/Rand325/Resultado_cliente_2.txt", 'r')
results3 = open("/content/Rand325/Resultado_cliente_3.txt", 'r')
results4 = open("/content/Rand325/Resultado_cliente_4.txt", 'r')
results5 = open("/content/Rand325/Resultado_cliente_5.txt", 'r')
results6 = open("/content/Rand325/Resultado_cliente_6.txt", 'r')
results7 = open("/content/Rand325/Resultado_cliente_7.txt", 'r')
results8 = open("/content/Rand325/Resultado_cliente_8.txt", 'r')
results9 = open("/content/Rand325/Resultado_cliente_9.txt", 'r')
results10 = open("/content/Rand325/Resultado_cliente_10.txt", 'r')

Lines1 = results1.readlines()
Lines2 = results2.readlines()
Lines3 = results3.readlines()
Lines4 = results4.readlines()
Lines5 = results5.readlines()
Lines6 = results6.readlines()
Lines7 = results7.readlines()
Lines8 = results8.readlines()
Lines9 = results9.readlines()
Lines10 = results10.readlines()

# %%
accuracies = [[],[],[],[],[],[],[],[],[],[]]
losses = [[],[],[],[],[],[],[],[],[],[]]

for line in Lines1:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[0].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[0].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines2:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[1].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[1].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines3:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[2].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[2].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines4:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[3].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[3].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines5:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[4].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[4].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines6:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[5].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[5].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines7:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[6].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[6].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines8:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[7].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[7].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines9:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[8].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[8].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines10:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[9].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[9].append(float(line.split(':')[2][1:].split(' ')[0]))

# %%
x2Mean = mean(accuracies,axis=0);
x2Interval = std(accuracies,axis=0)*1.96/sqrt(10);
x2Interval = std(accuracies,axis=0)
x2 = arange(len(x2Mean))

# %%
print( x2Mean[-1]*100,' \pm ', x2Interval[-1]*100)
# Out:
# 77.37400000000001  \pm  5.053211256221137

# %%
media1 = mean([accuracies[0], accuracies[1]],axis=0)*100
desvio1 = std([accuracies[0], accuracies[1]],axis=0)*100
media2 = mean([accuracies[2], accuracies[3]],axis=0)*100
desvio2 = std([accuracies[2], accuracies[3]],axis=0)*100
media3 = mean([accuracies[4], accuracies[5]],axis=0)*100
desvio3 = std([accuracies[4], accuracies[5]],axis=0)*100
media4 = mean([accuracies[6], accuracies[7]],axis=0)*100
desvio4 = std([accuracies[6], accuracies[7]],axis=0)*100
media5 = mean([accuracies[8], accuracies[9]],axis=0)*100
desvio5 = std([accuracies[8], accuracies[9]],axis=0)*100
print('Resultados 325 amostras')
print('1 e 2 :', media1[-1],' \pm ', desvio1[-1])
print('3 e 4 :', media2[-1],' \pm ', desvio2[-1])
print('5 e 6 :', media3[-1],' \pm ', desvio3[-1])
print('7 e 8 :', media4[-1],' \pm ', desvio4[-1])
print('9 e 10 :', media5[-1],' \pm ', desvio5[-1])
# Out:
# Resultados 325 amostras
# 1 e 2 : 81.575  \pm  0.2950000000000008
# 3 e 4 : 69.52499999999999  \pm  0.42500000000000315
# 5 e 6 : 73.27  \pm  0.31999999999999806
# 7 e 8 : 81.795  \pm  0.48499999999999654
# 9 e 10 : 80.705  \pm  0.5749999999999977

# %% [markdown]
# #### Leitura dos resultados do com amostragem de 1121 elementos:

# %%
results1 = open("/content/Rand1121/Resultado_cliente_1.txt", 'r')
results2 = open("/content/Rand1121/Resultado_cliente_2.txt", 'r')
results3 = open("/content/Rand1121/Resultado_cliente_3.txt", 'r')
results4 = open("/content/Rand1121/Resultado_cliente_4.txt", 'r')
results5 = open("/content/Rand1121/Resultado_cliente_5.txt", 'r')
results6 = open("/content/Rand1121/Resultado_cliente_6.txt", 'r')
results7 = open("/content/Rand1121/Resultado_cliente_7.txt", 'r')
results8 = open("/content/Rand1121/Resultado_cliente_8.txt", 'r')
results9 = open("/content/Rand1121/Resultado_cliente_9.txt", 'r')
results10 = open("/content/Rand1121/Resultado_cliente_10.txt", 'r')

Lines1 = results1.readlines()
Lines2 = results2.readlines()
Lines3 = results3.readlines()
Lines4 = results4.readlines()
Lines5 = results5.readlines()
Lines6 = results6.readlines()
Lines7 = results7.readlines()
Lines8 = results8.readlines()
Lines9 = results9.readlines()
Lines10 = results10.readlines()

# %%
accuracies = [[],[],[],[],[],[],[],[],[],[]]
losses = [[],[],[],[],[],[],[],[],[],[]]

for line in Lines1:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[0].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[0].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines2:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[1].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[1].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines3:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[2].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[2].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines4:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[3].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[3].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines5:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[4].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[4].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines6:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[5].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[5].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines7:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[6].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[6].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines8:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[7].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[7].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines9:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and  (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[8].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[8].append(float(line.split(':')[2][1:].split(' ')[0]))
for line in Lines10:
  if (not 'Epoch' in line) and (not 'ETA' in line) and (line != '\n') and (not '=' in line) and (not 'tensorflow' in line) and  (not 'flwr' in line) and  (not 'Classe' in line) and  (not 'venv' in line)and  (not 'TensorFlow' in line):
    losses[9].append(float(line.split(':')[1][1:].split(' ')[0]))
    accuracies[9].append(float(line.split(':')[2][1:].split(' ')[0]))

# %%
x3Mean = mean(accuracies,axis=0);
x3Interval = std(accuracies,axis=0)*1.96/sqrt(10);
x3Interval = std(accuracies,axis=0)
x3 = arange(len(x3Mean))

# %%
print( x3Mean[-1]*100,' \pm ', x3Interval[-1]*100)
# Out:
# 77.911  \pm  4.521423337843957

# %%
media1 = mean([accuracies[0], accuracies[1]],axis=0)*100
desvio1 = std([accuracies[0], accuracies[1]],axis=0)*100
media2 = mean([accuracies[2], accuracies[3]],axis=0)*100
desvio2 = std([accuracies[2], accuracies[3]],axis=0)*100
media3 = mean([accuracies[4], accuracies[5]],axis=0)*100
desvio3 = std([accuracies[4], accuracies[5]],axis=0)*100
media4 = mean([accuracies[6], accuracies[7]],axis=0)*100
desvio4 = std([accuracies[6], accuracies[7]],axis=0)*100
media5 = mean([accuracies[8], accuracies[9]],axis=0)*100
desvio5 = std([accuracies[8], accuracies[9]],axis=0)*100
print('Resultados 1121 amostras')
print('1 e 2 :', media1[-1],' \pm ', desvio1[-1])
print('3 e 4 :', media2[-1],' \pm ', desvio2[-1])
print('5 e 6 :', media3[-1],' \pm ', desvio3[-1])
print('7 e 8 :', media4[-1],' \pm ', desvio4[-1])
print('9 e 10 :', media5[-1],' \pm ', desvio5[-1])
# Out:
# Resultados 1121 amostras
# 1 e 2 : 81.36  \pm  0.22999999999999687
# 3 e 4 : 70.53  \pm  0.09000000000000119
# 5 e 6 : 74.91000000000001  \pm  0.040000000000001146
# 7 e 8 : 82.46  \pm  0.49000000000000155
# 9 e 10 : 80.295  \pm  0.39499999999999535

# %% [markdown]
# #### Plotando os resultados no primeiro grupo

# %%
plt.figure(figsize=(10,6))
plt.figure(figsize=(6,4))
plt.plot(x, x1Mean, 'b-', label='Original: 2100 amostras')
plt.fill_between(x, x1Mean - x1Interval, x1Mean + x1Interval, color='b', alpha=0.3)

plt.plot(x2, x2Mean, 'g-',label='Proposta: 325 amostras aleatorias')
plt.fill_between(x2, x2Mean - x2Interval, x2Mean + x2Interval, color='g', alpha=0.4)

plt.plot(x3, x3Mean, 'r-',label='Proposta: 1121 amostras aleatorias')
plt.fill_between(x3, x3Mean - x3Interval, x3Mean + x3Interval, color='r', alpha=0.2)

plt.ylabel('Acurácia', fontsize=10)
plt.ylim(0.7, 0.87)
plt.title('Acurácia média em todos os clientes')
plt.xlabel('Época', fontsize=10)
plt.legend()
plt.show()

# %% [markdown]
# #### Analise dos dados para construcao de tabelas:

# %%
results1 = open("/content/Resultado_servidor_1_2.txt", 'r')
results2 = open("/content/Resultado_servidor_3_4.txt", 'r')
results3 = open("/content/Resultado_servidor_5_6.txt", 'r')
results4 = open("/content/Resultado_servidor_7_8.txt", 'r')
results5 = open("/content/Resultado_servidor_9_10.txt", 'r')

Lines1 = results1.readlines()
Lines2 = results2.readlines()
Lines3 = results3.readlines()
Lines4 = results4.readlines()
Lines5 = results5.readlines()

# %%
results1 = open("/content/Rand325/Resultado_servidor_1_2.txt", 'r')
results2 = open("/content/Rand325/Resultado_servidor_3_4.txt", 'r')
results3 = open("/content/Rand325/Resultado_servidor_5_6.txt", 'r')
results4 = open("/content/Rand325/Resultado_servidor_7_8.txt", 'r')
results5 = open("/content/Rand325/Resultado_servidor_9_10.txt", 'r')

Lines1 = results1.readlines()
Lines2 = results2.readlines()
Lines3 = results3.readlines()
Lines4 = results4.readlines()
Lines5 = results5.readlines()

# %%
results1 = open("/content/Rand1121/Resultado_servidor_1_2.txt", 'r')
results2 = open("/content/Rand1121/Resultado_servidor_3_4.txt", 'r')
results3 = open("/content/Rand1121/Resultado_servidor_5_6.txt", 'r')
results4 = open("/content/Rand1121/Resultado_servidor_7_8.txt", 'r')
results5 = open("/content/Rand1121/Resultado_servidor_9_10.txt", 'r')

Lines1 = results1.readlines()
Lines2 = results2.readlines()
Lines3 = results3.readlines()
Lines4 = results4.readlines()
Lines5 = results5.readlines()

# %%
from datetime import datetime
times = [[],[],[],[],[]]
days = [[],[],[],[],[]]

for line in Lines1:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[0].append( line.split(' ')[3].split(',')[0])
    days[0].append(line.split(' ')[2])
for line in Lines2:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[1].append( line.split(' ')[3].split(',')[0])
    days[1].append(line.split(' ')[2])
for line in Lines3:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[2].append( line.split(' ')[3].split(',')[0])
    days[2].append(line.split(' ')[2])
for line in Lines4:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[3].append( line.split(' ')[3].split(',')[0])
    days[3].append(line.split(' ')[2])
for line in Lines5:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[4].append( line.split(' ')[3].split(',')[0])
    days[4].append(line.split(' ')[2])


seconds = [[],[],[],[],[]]
hours = [[],[],[],[],[]]

print(len(times), len(times[0]))
for i in range(0,len(times)):
  for j in range(0, len(times[0])):

    AcDepart = days[i][j] + ' ' + times[i][j]
    AcDepart_ = datetime.strptime(AcDepart, '%Y-%m-%d %H:%M:%S')
    AcArrival = days[i][0] + ' ' + times[i][0]
    AcArrival_ = datetime.strptime(AcArrival, '%Y-%m-%d %H:%M:%S')
    ActualSeconds = (AcDepart_ - AcArrival_).total_seconds()
    ActualHours = ActualSeconds/3600
    seconds[i].append(ActualSeconds)
    hours[i].append(ActualHours)
# Out:
# 5 400

# %%
ultimos_segundos = []
for i in range(0,5):
  ultimos_segundos.append(seconds[i][-1])

m_segundos = mean(ultimos_segundos,axis=0)
d_segundos = std(ultimos_segundos,axis=0)
print( m_segundos,' \pm ', d_segundos)
# Out:
# 1502.0  \pm  7.402702209328699

# %%
# Out:
# 2503.0  \pm  19.05780679931455

# %% [markdown]
# #### Leitura dos arquivos do servidor para obtenção do tempo de treinamento

# %%
from datetime import datetime

# %%
results1 = open("/content/Resultado_servidor_9_10.txt", 'r')
results2 = open("/content/Rand325/Resultado_servidor_9_10.txt", 'r')
results3 = open("/content/Rand1121/Resultado_servidor_9_10.txt", 'r')

Lines1 = results1.readlines()
#Lines1 = results2.readlines()
#results2 = open("/content/Rand325/Resultado_servidor_9_10.txt", 'r')
Lines2 = results2.readlines()
Lines3 = results3.readlines()

times = [[],[],[]]
days = [[],[],[]]

for line in Lines1:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[0].append( line.split(' ')[3].split(',')[0])
    days[0].append(line.split(' ')[2])
for line in Lines2:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[1].append( line.split(' ')[3].split(',')[0])
    days[1].append(line.split(' ')[2])
for line in Lines3:
  if (line != '\n') and ('evaluate_round' in line) and ('received' in line):
    times[2].append( line.split(' ')[3].split(',')[0])
    days[2].append(line.split(' ')[2])

seconds = [[],[],[]]
hours = [[],[],[]]

print(len(times), len(times[0]))
for i in range(0,len(times)):
  for j in range(0, len(times[0])):

    AcDepart = days[i][j] + ' ' + times[i][j]
    AcDepart_ = datetime.strptime(AcDepart, '%Y-%m-%d %H:%M:%S')
    AcArrival = days[i][0] + ' ' + times[i][0]
    AcArrival_ = datetime.strptime(AcArrival, '%Y-%m-%d %H:%M:%S')
    ActualSeconds = (AcDepart_ - AcArrival_).total_seconds()
    ActualHours = ActualSeconds/3600
    seconds[i].append(ActualSeconds)
    hours[i].append(ActualHours)
# Out:
# 3 400

# %%
for i in range(0,3):
  print(seconds[i][-1])
# Out:
# 2510.0
# 703.0
# 1513.0

# %%
x = [i for i in range(0, len(seconds[0]))]
labels=['Original: 2100 amostras','Proposta: 325 amostras aleatorias', 'Proposta: 1121 amostras aleatorias' ]
cor = ['b', 'g', 'r']

plt.figure(figsize=(6,4))
for i in range(0, len(seconds)):
  plt.plot(x, seconds[i], color=cor[i],label=labels[i])
plt.ylabel('Tempo (s)', fontsize=10)
plt.title('Tempo de treinamento no quinto grupo')
plt.xlabel('Época', fontsize=10)
plt.legend()
plt.show()
